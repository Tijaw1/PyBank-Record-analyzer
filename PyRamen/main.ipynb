# %%
import numpy as np
from pathlib import Path
import csv

csvpath_menu = Path ('C:/Users/Endalkachew Desta/Downloads/HW2_PyRamen_Resources_menu_data.csv')
csvpath_sales = Path ('C:/Users/Endalkachew Desta/Downloads/HW2_PyRamen_Resources_sales_data.csv')

menu = []
#sales = []
LineNum = 0
with open (csvpath_menu,'r') as csvmenu:
    csvdata1=csv.reader(csvmenu, delimiter = ',')
        
    header = next(csvdata1)
    LineNum +=1
        
    print(f"{header} <---- Header")
    
    for row in csvdata1:
        #print(row)
        
        item = row[0]
        category = row[1]
        description = row[2]
        price = float(row[3])
        cost = int(row[4])
        menu.append(item)
        menu.append(category)
        menu.append(description)
        menu.append(price)
        menu.append(cost)
print('-------------------------------------------------------------')
sales = []
with open (csvpath_sales,'r') as csvsales:
    csvdata2=csv.DictReader(csvsales)
    
            
    header = next(csvdata2)
    LineNum +=1
        
    print(f"{header} ")
    
    for row_sale in csvdata2:
        #print(row_sale)
        
        Line_Item = row_sale['Line_Item_ID']
        Date = row_sale['Date']
        Credit_CardNumber = row_sale['Credit_Card_Number']
        Quantity = (row_sale['Quantity'])
        Menu_Item = row_sale['Menu_Item']
        sales.append(Line_Item)
        sales.append(Date),
        sales.append(Credit_CardNumber)
        sales.append(Quantity)
        sales.append(Menu_Item)
        report = {}
        count = 0
        quantity = 0
        sale_item = list(row_sale['Menu_Item'])
        #print(sale_item)
    for item in sale_item:
        if sale_item == 'spicy miso ramen':
            index=sale_item.index(item)
            value=Quantity[index]
            count=count+int(value) 
            print(count)
        elif sale_item == 'tori paitan ramen':
            index=sale_item.index(item)
            value=Quantity[index]
            count=count+int(value) 
        elif sale_item == 'truffle butter ramen':
            index=sale_item.index(item)
            value=Quantity[index]
            count=count+int(value) 
        elif sale_item == 'tonkotsu ramen':
            index=sale_item.index(item)
            value=Quantity[index]
            count=count+int(value) 
        elif sale_item == 'vegetarian spicy miso':
            index=sale_item.index(item)
            value=Quantity[index]
            count=count+int(value) 
        elif sale_item == 'shio ramen':
            index=sale_item.index(item)
            value=Quantity[index]
            count=count+int(value) 
        elif sale_item == 'miso crab ramen':
            index=sale_item.index(item)
            value=Quantity[index]
            count=count+int(value) 
        elif sale_item == 'nagomi shoyu':
            index=sale_item.index(item)
            value=Quantity[index]
            count=count+int(value) 
        elif sale_item == 'soft-shell miso crab ramen':
            index=sale_item.index(item)
            value=Quantity[index]
            count=count+int(value) 
        elif sale_item == 'burnt garlic tonkotsu ramen':
            index=sale_item.index(item)
            value=Quantity[index]
            count=count+int(value) 
        elif sale_item == 'vegetarian curry + king trumpet mushroom ramen':
            index=sale_item.index(item)
            value=Quantity[index]
            count=count+int(value) 
        report[item]=count
        print(report)
